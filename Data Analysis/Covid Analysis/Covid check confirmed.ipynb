# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
confirmed_covid=pd.read_csv(r"C:\Users\Abraham\Desktop\Solo\Bootcamp\portfolio\Caso Covid\Data Raw\covid19_Confirmed_dataset.csv")

# %%
confirmed_covid.shape
confirmed_covid.head(5)
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
uselesscols=["Lat","Long"]
confirmed_covid.drop(uselesscols,axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28068\1278752098.py in <module>
#       1 uselesscols=["Lat","Long"]
# ----> 2 confirmed_covid.drop(uselesscols,axis=1,inplace=True)
#
# c:\Users\Abraham\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Abraham\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
aggregated_confirmed= confirmed_covid.groupby("Country/Region").sum()

# %%
aggregated_confirmed.loc["Italy"]
# Out:
# 1/22/20         0
# 1/23/20         0
# 1/24/20         0
# 1/25/20         0
# 1/26/20         0
#             ...
# 4/26/20    197675
# 4/27/20    199414
# 4/28/20    201505
# 4/29/20    203591
# 4/30/20    205463
# Name: Italy, Length: 100, dtype: int64

# %%
aggregated_confirmed.loc["Italy"].diff().max()
# Out:
# 6557.0

# %%
#compare Italy and Spain

aggregated_confirmed.loc["Italy"].diff().plot()
aggregated_confirmed.loc["Spain"].diff().plot()
aggregated_confirmed.loc["China"].diff().plot()
aggregated_confirmed.loc["Germany"].diff().plot()
aggregated_confirmed.loc["France"].diff().plot()

plt.legend()

# %%
#Creating a list with the countries
countries=list(aggregated_confirmed.index)

# %%
max_infection_rates= []
for i in countries:
   max_infection_rates=
   
   
   
   #max_infection_rates.append(aggregated_confirmed.loc[i].diff().max())

# %%
def maxinf(i):
    return i.diff().max()

# %%
aggregated_confirmed2=aggregated_confirmed.copy()

# %%
aggregated_confirmed2["Maxinfection"]=aggregated_confirmed2.apply(maxinf,axis=1)

# %%
aggregated_confirmed2
# Out:
#                     1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan               0        0        0        0        0        0
# Albania                   0        0        0        0        0        0
# Algeria                   0        0        0        0        0        0
# Andorra                   0        0        0        0        0        0
# Angola                    0        0        0        0        0        0
# ...                     ...      ...      ...      ...      ...      ...
# West Bank and Gaza        0        0        0        0        0        0
# Western Sahara            0        0        0        0        0        0
# Yemen                     0        0        0        0        0        0
# Zambia                    0        0        0        0        0        0
# Zimbabwe                  0        0        0        0        0        0
#
# ...

# %%
#covid only max infection 

agregated_infection=pd.DataFrame(aggregated_confirmed2["Maxinfection"])
agregated_infection.head(2)
# Out:
#                 Maxinfection
# Country/Region
# Afghanistan            232.0
# Albania                 34.0

# %% [markdown]
# ## Happiness report

# %%
Happiness_csv=pd.read_csv(r"C:\Users\Abraham\Desktop\Solo\Bootcamp\portfolio\Caso Covid\Data Raw\worldwide_happiness_report.csv")

# %%
Happiness_csv.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
useless=['Overall rank', 'Score']

# %%
Happiness_csv.drop(useless,axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28068\1424396341.py in <module>
# ----> 1 Happiness_csv.drop(useless,axis=1,inplace=True)
#       2 Happiness_csv
#
# c:\Users\Abraham\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Abraham\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
Happiness_csv.set_index("Country or region",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28068\1081146268.py in <module>
# ----> 1 Happiness_csv.set_index("Country or region",inplace=True)
#       2 Happiness_csv
#
# c:\Users\Abraham\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# c:\Users\Abraham\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5449
#    5450         if missing:
# -> 5451             raise KeyError(f"None of {missing} are in the columns")
#    5452
#    5453         if inplace:
#
# ...

# %%
Happiness_csv
# Out:
#                           GDP per capita  Social support  \
# Country or region
# Finland                            1.340           1.587
# Denmark                            1.383           1.573
# Norway                             1.488           1.582
# Iceland                            1.380           1.624
# Netherlands                        1.396           1.522
# ...                                  ...             ...
# Rwanda                             0.359           0.711
# Tanzania                           0.476           0.885
# Afghanistan                        0.350           0.517
# Central African Republic           0.026           0.000
# South Sudan                        0.306           0.575
#
#                           Healthy life expectancy  \
# Country or region
# Finland                                     0.986
# Denmark                                     0.996
# Norway                                      1.028
# ...

# %% [markdown]
# ## Joining files

# %%
agregated_infection2=agregated_infection.copy()
Happiness_csv2=Happiness_csv.copy()

# %%
agregated_infection2.shape
# Out:
# (187, 1)

# %%
Happiness_csv2.shape
# Out:
# (156, 6)

# %%
data=agregated_infection2.join(Happiness_csv2,how="inner")
data
# Out:
#              Maxinfection  GDP per capita  Social support  \
# Afghanistan         232.0           0.350           0.517
# Albania              34.0           0.947           0.848
# Algeria             199.0           1.002           1.160
# Argentina           291.0           1.092           1.432
# Armenia             134.0           0.850           1.055
# ...                   ...             ...             ...
# Venezuela            29.0           0.960           1.427
# Vietnam              19.0           0.741           1.346
# Yemen                 5.0           0.287           1.163
# Zambia                9.0           0.578           1.058
# Zimbabwe              8.0           0.366           1.114
#
#              Healthy life expectancy  Freedom to make life choices  \
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# ...

# %%
data.corr()
# Out:
#                               Maxinfection  GDP per capita  Social support  \
# Maxinfection                      1.000000        0.250118        0.191958
# GDP per capita                    0.250118        1.000000        0.759468
# Social support                    0.191958        0.759468        1.000000
# Healthy life expectancy           0.289263        0.863062        0.765286
# Freedom to make life choices      0.078196        0.394603        0.456246
# Generosity                       -0.114635       -0.103870       -0.061361
# Perceptions of corruption         0.097703        0.311577        0.203225
#
#                               Healthy life expectancy  \
# Maxinfection                                 0.289263
# GDP per capita                               0.863062
# Social support                               0.765286
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.427892
# ...

# %% [markdown]
# ### Visualización

# %%
aggregated_confirmed2.loc["China"].drop("Maxinfection").plot()
plt.legend()

# %%
aggregated_confirmed2.loc["Spain"].drop("Maxinfection").plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Comparando variables

# %%
x=data["GDP per capita"]
y=data["Maxinfection"]
sns.scatterplot(x=x,y=np.log(y))
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='Maxinfection'>

# %%
sns.regplot(x=x,y=np.log(y))
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='Maxinfection'>

# %%
df = pd.DataFrame({'x': x, 'y': np.log(y)})
df.to_csv('data.csv', index=False)
